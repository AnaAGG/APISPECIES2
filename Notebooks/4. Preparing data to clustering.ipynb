# %% [markdown]
# ## Libraries

# %%
import sys
sys.path.append('../')

# %%
import pandas as pd
from functools import partial, reduce
from geopy.geocoders import Nominatim
from sklearn.preprocessing import StandardScaler
import src.functions_cluster as cl

# %% [markdown]
# ## Objectives

# %% [markdown]
# The objective of this data frame is to load the data of the climatic variables that will be used for the clustering model.
#
# This dataset must be prepared to join it with the data of the species that it had downloaded from the GBIF API (Notebook1). After loading the data and putting all the files together, I'm going to create a new column in the dataframe named `community` that will allow us to join this dataframe with the species one

# %% [markdown]
# ## Load the data

# %%
anual_prec = cl.reader("../Predictors/anual_prec.csv", "anual_prec")
elevation = cl.reader("../Predictors/elevation.csv", "elevation")
isothermality = cl.reader("../Predictors/isothermality.csv", "isothermality")
max_warmest = cl.reader("../Predictors/max_warmest.csv", "max_warmest")
mean_temp = cl.reader("../Predictors/mean_temp.csv", "mean_temp")
min_coldest = cl.reader("../Predictors/min_coldest.csv", "min_coldest")
precip_season = cl.reader("../Predictors/precip_season.csv", "precip_season")
temp_range = cl.reader("../Predictors/temp_range.csv", "temp_range")
temp_season = cl.reader("../Predictors/temp_season.csv", "temp_season")

# %%
#Uno todos los ficheros independientes en un dataframe. Como todos tienen las mismas coordenadas, la union se hace en base a 
    ## dos columnas
dfs = [min_coldest, elevation, anual_prec, isothermality, max_warmest, mean_temp, precip_season,  temp_season, temp_range]

merge = partial(pd.merge, on=['lon', 'lat'], how='outer')
climate = reduce(merge, dfs)

# %%
#creamos una nueva columna que nos junte la lat y long en una nueva columna
climate["new"] = climate["lat"].map(str) + "," + climate["long"].map(str)
climate = climate.drop_duplicates(["long", "lat"])

# %%
climate["province"] = climate.new.apply(cl.get_community)

# %% [markdown]
# ## Exploring the data set and some plots

# %%
climate = pd.read_csv("data_cli.csv", sep =  ";")

# %%
climate.head()
# Out:
#    min_temp  long   lat  max_temp  elevation  isothermality  mean_temp  \
# 0       0.4  -5.6  41.9      28.9        704           39.3       12.3
# 1       0.4  -5.5  41.9      29.1        701           39.2       12.3
# 2       0.4  -5.4  41.9      29.0        698           39.4       12.3
# 3       0.2  -5.3  41.9      28.9        718           39.4       12.2
# 4       0.1  -5.2  41.9      28.8        739           39.4       12.1
#
#    precip  seasonal_temp        new        community
# 0    38.7          615.6  41.9,-5.6  Castilla y Leon
# 1    37.4          620.7  41.9,-5.5  Castilla y Leon
# 2    35.4          618.3  41.9,-5.4  Castilla y Leon
# 3    34.3          619.1  41.9,-5.3  Castilla y Leon
# 4    34.0          620.6  41.9,-5.2  Castilla y Leon

# %%
climate.drop(["new", "lat", "long"], axis = 1, inplace = True)

# %%
climate.describe().transpose()
# Out:
#                 count        mean         std    min    25%    50%    75%  \
# min_temp       6077.0    2.012572    3.447542  -10.0   -0.3    1.7    4.3
# max_temp       6077.0   29.844068    3.298934   17.7   27.7   29.9   32.5
# elevation      6077.0  609.931545  409.940727   -3.0  272.0  599.0  858.0
# isothermality  6077.0   40.302337    2.822187   29.6   38.6   40.0   41.8
# mean_temp      6077.0   13.854139    2.727410    1.1   11.9   14.3   15.9
# precip         6077.0   45.450485   14.889985   14.6   33.0   44.5   56.5
# seasonal_temp  6077.0  594.713790  102.104825  192.0  547.4  616.4  661.6
#
#                   max
# min_temp         15.1
# max_temp         36.5
# elevation      2637.0
# isothermality    56.1
# mean_temp        21.0
# precip           92.2
# seasonal_temp   771.7

# %%
climate = climate.groupby('community', as_index=False)['min_temp', 'max_temp', 'elevation', 'isothermality', 'mean_temp', 'precip', 'seasonal_temp'].mean()
# Out:
# <ipython-input-27-780e9d8f3ef6>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   climate = climate.groupby('community', as_index=False)['min_temp', 'max_temp', 'elevation', 'isothermality', 'mean_temp', 'precip', 'seasonal_temp'].mean()

# %%
climate
# Out:
#                community   min_temp   max_temp   elevation  isothermality  \
# 0                Algarve   6.831667  29.341667  168.000000      43.000000
# 1              Andalucia   3.522201  32.681694  469.798442      41.498832
# 2                 Aragon  -0.739964  29.081172  827.101243      39.299112
# 3               Asturias   2.573077  25.332692  565.346154      40.632692
# 4        Castilla y Leon  -0.689243  27.802086  932.570801      38.952689
# 5     Castilla-La Mancha  -0.126208  32.375121  830.712560      39.228744
# 6               Cataluna   0.326870  27.175069  642.614958      37.685873
# 7    Comunidad de Madrid   0.270455  30.643182  820.886364      37.052273
# 8   Comunitat Valenciana   1.987302  30.616667  489.436508      41.116270
# 9                Euskadi   0.290909  25.663636  696.818182      40.490909
# 10           Extremadura   3.056591  32.501364  438.981818      39.718864
# 11               Galicia   2.543750  24.800000  587.450000      40.601875
# 12         Illes Balears   5.608621  28.912931  101.456897      39.147414
# 13        Islas Canarias  12.188050  26.059119  366.540881      48.155346
# 14              La Rioja  -0.854717  26.271698  906.150943      39.843396
# 15                Murcia   2.186614  32.935433  485.905512      41.646457
# 16    Navarra - Nafarroa   1.417910  28.247761  487.343284      38.177612
# 17                 Norte   3.096629  25.742135  484.556180      41.224157
# 18                 Otras   4.606355  27.349164  368.806020      41.272241
# 19              Portugal   6.080923  29.894769  154.470769      43.178769
#
#     mean_temp     precip  seasonal_temp
# 0   16.618333  70.476667     450.486667
# 1   15.922006  60.162025     603.885784
# 2   11.883126  28.455240     646.578153
# 3   12.430769  50.832692     489.126923
# 4   11.116795  35.545774     620.490889
# 5   13.436353  39.484300     701.187077
# 6   12.259280  26.418006     604.932410
# 7   13.006818  38.130682     683.940909
# 8   14.707540  36.485317     610.363492
# 9   10.900000  24.527273     549.681818
# 10  15.425227  55.407273     626.537727
# 11  12.025625  47.464375     480.133750
# 12  16.196552  46.415517     525.504310
# 13  18.465409  79.138365     260.986792
# 14  10.371698  26.003774     588.584906
# 15  15.711811  40.817323     646.435433
# 16  12.714925  23.585075     586.655224
# 17  13.031461  53.594944     480.497191
# 18  14.490635  56.739130     481.167893
# 19  16.251077  60.013846     480.531692

# %%
#guardo este csv por si las mosquis
climate.to_csv("climate.csv", index = 0)

# %% [markdown]
# Now I am going to standardize the data since each of them has different scales. Since we have a categorical variable that we cannot standardize, I am going to make a copy of my dataframe and then standardize only for continuous variables.

# %%
scaled_features = climate.copy()

# %%
col_names = ['min_temp', 'max_temp', 'elevation', 'isothermality', 'mean_temp', 'precip', 'seasonal_temp']
features = scaled_features[col_names]
scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)

# %% [markdown]
# Now, don't create a new dataframe but assign the result to those two columns:

# %%
scaled_features[col_names] = features
scaled_features
# Out:
#                community  min_temp  max_temp  elevation  isothermality  \
# 0                Algarve  1.319279  0.259189  -1.565288       1.028701
# 1              Andalucia  0.260258  1.550703  -0.299635       0.386286
# 2                 Aragon -1.103625  0.158462   1.198785      -0.555070
# 3               Asturias -0.043460 -1.290991   0.101063       0.015627
# 4        Castilla y Leon -1.087394 -0.336132   1.641093      -0.703320
# 5     Castilla-La Mancha -0.907225  1.432158   1.213930      -0.585184
# 6               Cataluna -0.762241 -0.578585   0.425105      -1.245446
# 7    Comunidad de Madrid -0.780294  0.762456   1.172722      -1.516591
# 8   Comunitat Valenciana -0.230906  0.752203  -0.217279       0.222571
# 9                Euskadi -0.773748 -1.163023   0.652417      -0.045048
# 10           Extremadura  0.111264  1.480974  -0.428871      -0.375440
# 11               Galicia -0.052844 -1.496971   0.193760       0.002439
# 12         Illes Balears  0.927907  0.093407  -1.844349      -0.619989
# 13        Islas Canarias  3.033310 -1.010098  -0.732667       3.234899
# 14              La Rioja -1.140346 -0.927899   1.530296      -0.322147
# 15                Murcia -0.167127  1.648819  -0.232087       0.449461
# 16    Navarra - Nafarroa -0.413110 -0.163799  -0.226058      -1.035009
# 17                 Norte  0.124076 -1.132669  -0.237746       0.268741
# 18                 Otras  0.607184 -0.511267  -0.723167       0.289318
# 19              Portugal  1.079043  0.473062  -1.622025       1.105204
#
#     mean_temp    precip  seasonal_temp
# 0    1.274503  1.654740      -1.056714
# 1    0.954123  0.985189       0.481245
# 2   -0.904162 -1.072983       0.909273
# 3   -0.652192  0.379597      -0.669312
# 4   -1.256750 -0.612718       0.647726
# 5   -0.189524 -0.357057       1.456775
# 6   -0.731094 -1.205226       0.491738
# 7   -0.387152 -0.444924       1.283867
# 8    0.395348 -0.551729       0.546190
# 9   -1.356497 -1.327958      -0.062197
# 10   0.725556  0.676546       0.708350
# 11  -0.838598  0.160951      -0.759477
# 12   1.080441  0.092867      -0.304597
# 13   2.124340  2.216995      -2.956615
# 14  -1.599568 -1.232115       0.327840
# 15   0.857413 -0.270527       0.907842
# 16  -0.521452 -1.389119       0.308494
# 17  -0.375814  0.558902      -0.755833
# 18   0.295551  0.763000      -0.749108
# 19   1.105528  0.975571      -0.755487

# %% [markdown]
# ## Load species data

# %%
sp = pd.read_csv("species_def.csv", sep = ";")

# %%
sp.head()
# Out:
#     long     lat  locality  province  community  year month   kingdom  \
# 0 -1.856  37.237   Almeria   Almeria  Andalucia  2012   Oct  Animalia
# 1 -2.256  36.797   Almeria   Almeria  Andalucia  2013   Apr  Animalia
# 2 -2.294  36.835   Almeria   Almeria  Andalucia  2017   Oct  Animalia
# 3 -2.286  36.820   Almeria   Almeria  Andalucia  2017   Oct  Animalia
# 4 -2.224  36.763   Almeria   Almeria  Andalucia  2017   Aug  Animalia
#
#       class          family       genus                 species  \
# 0  Reptilia      Colubridae  Hemorrhois  Hemorrhois hippocrepis
# 1  Reptilia  Chamaeleonidae   Chamaeleo    Chamaeleo chamaeleon
# 2  Reptilia  Chamaeleonidae   Chamaeleo    Chamaeleo chamaeleon
# 3  Reptilia  Chamaeleonidae   Chamaeleo    Chamaeleo chamaeleon
# 4  Reptilia  Chamaeleonidae   Chamaeleo    Chamaeleo chamaeleon
#
#             common_name
# 0  Horseshoe Whip Snake
# 1      Common Chameleon
# 2      Common Chameleon
# 3      Common Chameleon
# 4      Common Chameleon

# %%
merged = pd.merge(scaled_features, sp, how='inner', left_on='community', right_on='community')

# %%
merged.head()
# Out:
#    community  min_temp  max_temp  elevation  isothermality  mean_temp  \
# 0  Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
# 1  Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
# 2  Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
# 3  Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
# 4  Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
#
#      precip  seasonal_temp   long     lat  locality  province  year month  \
# 0  0.985189       0.481245 -1.856  37.237   Almeria   Almeria  2012   Oct
# 1  0.985189       0.481245 -2.256  36.797   Almeria   Almeria  2013   Apr
# 2  0.985189       0.481245 -2.294  36.835   Almeria   Almeria  2017   Oct
# 3  0.985189       0.481245 -2.286  36.820   Almeria   Almeria  2017   Oct
# 4  0.985189       0.481245 -2.224  36.763   Almeria   Almeria  2017   Aug
#
#     kingdom     class          family       genus                 species  \
# 0  Animalia  Reptilia      Colubridae  Hemorrhois  Hemorrhois hippocrepis
# 1  Animalia  Reptilia  Chamaeleonidae   Chamaeleo    Chamaeleo chamaeleon
# 2  Animalia  Reptilia  Chamaeleonidae   Chamaeleo    Chamaeleo chamaeleon
# 3  Animalia  Reptilia  Chamaeleonidae   Chamaeleo    Chamaeleo chamaeleon
# 4  Animalia  Reptilia  Chamaeleonidae   Chamaeleo    Chamaeleo chamaeleon
#
#             common_name
# 0  Horseshoe Whip Snake
# 1      Common Chameleon
# 2      Common Chameleon
# 3      Common Chameleon
# 4      Common Chameleon

# %%
merged.drop_duplicates()
# Out:
#       community  min_temp  max_temp  elevation  isothermality  mean_temp  \
# 0     Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
# 1     Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
# 2     Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
# 3     Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
# 4     Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
# ...         ...       ...       ...        ...            ...        ...
# 9681      Norte  0.124076 -1.132669  -0.237746       0.268741  -0.375814
# 9682      Norte  0.124076 -1.132669  -0.237746       0.268741  -0.375814
# 9683      Norte  0.124076 -1.132669  -0.237746       0.268741  -0.375814
# 9684      Norte  0.124076 -1.132669  -0.237746       0.268741  -0.375814
# 9685      Norte  0.124076 -1.132669  -0.237746       0.268741  -0.375814
#
#         precip  seasonal_temp   long     lat  \
# 0     0.985189       0.481245 -1.856  37.237
# 1     0.985189       0.481245 -2.256  36.797
# 2     0.985189       0.481245 -2.294  36.835
# 3     0.985189       0.481245 -2.286  36.820
# 4     0.985189       0.481245 -2.224  36.763
# ...        ...            ...    ...     ...
# 9681  0.558902      -0.755833 -4.390  43.387
# 9682  0.558902      -0.755833 -4.033  43.434
# 9683  0.558902      -0.755833 -4.033  43.434
# 9684  0.558902      -0.755833 -4.033  43.434
# 9685  0.558902      -0.755833 -4.033  43.434
#
#                                 locality   province  year month   kingdom  \
# 0                                Almeria    Almeria  2012   Oct  Animalia
# 1                                Almeria    Almeria  2013   Apr  Animalia
# 2                                Almeria    Almeria  2017   Oct  Animalia
# 3                                Almeria    Almeria  2017   Oct  Animalia
# 4                                Almeria    Almeria  2017   Aug  Animalia
# ...                                  ...        ...   ...   ...       ...
# 9681  Ria de San Vicente de La Barquera   Cantabria  2004   Jan  Animalia
# 9682                     Ria de Suances   Cantabria  2001   Jan  Animalia
# 9683                     Ria de Suances   Cantabria  2002   Jan  Animalia
# 9684                     Ria de Suances   Cantabria  2003   Jan  Animalia
# 9685                     Ria de Suances   Cantabria  2003   Jan  Animalia
#
#          class          family        genus                 species  \
# 0     Reptilia      Colubridae   Hemorrhois  Hemorrhois hippocrepis
# 1     Reptilia  Chamaeleonidae    Chamaeleo    Chamaeleo chamaeleon
# 2     Reptilia  Chamaeleonidae    Chamaeleo    Chamaeleo chamaeleon
# 3     Reptilia  Chamaeleonidae    Chamaeleo    Chamaeleo chamaeleon
# 4     Reptilia  Chamaeleonidae    Chamaeleo    Chamaeleo chamaeleon
# ...        ...             ...          ...                     ...
# 9681      Aves   Podicipedidae     Podiceps      Podiceps cristatus
# 9682      Aves   Podicipedidae  Tachybaptus  Tachybaptus ruficollis
# 9683      Aves   Podicipedidae  Tachybaptus  Tachybaptus ruficollis
# 9684      Aves   Podicipedidae     Podiceps      Podiceps cristatus
# 9685      Aves   Podicipedidae  Tachybaptus  Tachybaptus ruficollis
#
#                common_name
# 0     Horseshoe Whip Snake
# 1         Common Chameleon
# 2         Common Chameleon
# 3         Common Chameleon
# 4         Common Chameleon
# ...                    ...
# 9681     Somormujo lavanco
# 9682       Zampullin comun
# 9683       Zampullin comun
# 9684     Somormujo lavanco
# 9685       Zampullin comun
#
# [9684 rows x 20 columns]

# %% [markdown]
# Now, I will clean the dataset to keep only the relevant variables for the cluster analysis

# %%
merged.drop(["locality", "province", "year", "month", "kingdom", "class", "family", "genus", "common_name" ], axis = 1,  inplace = True)

# %%
merged.head()
# Out:
#    community  min_temp  max_temp  elevation  isothermality  mean_temp  \
# 0  Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
# 1  Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
# 2  Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
# 3  Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
# 4  Andalucia  0.260258  1.550703  -0.299635       0.386286   0.954123
#
#      precip  seasonal_temp   long     lat                 species
# 0  0.985189       0.481245 -1.856  37.237  Hemorrhois hippocrepis
# 1  0.985189       0.481245 -2.256  36.797    Chamaeleo chamaeleon
# 2  0.985189       0.481245 -2.294  36.835    Chamaeleo chamaeleon
# 3  0.985189       0.481245 -2.286  36.820    Chamaeleo chamaeleon
# 4  0.985189       0.481245 -2.224  36.763    Chamaeleo chamaeleon

# %%
merged.to_csv("sp_climate.csv", index = 0)
